# %%
import cv2
import matplotlib.pyplot as plt

# %%
#versoes das bibliotecas
print("Loaded OpenCV version: {}".format(cv2.__version__))
print("Matplotlib version: {}".format(matplotlib.__version__))
# Out:
# Loaded OpenCV version: 4.5.4
# Matplotlib version: 3.5.0

# %%
#ler uma imagem
image = cv2.imread('img/russian.jpg')

# %%
#comprimento, altura e canais de uma imagem
print("comprimento (w): %d pixels" % (image.shape[1]))
print("altura (h): %d pixels" % (image.shape[0]))
print("canais (w): %d pixels" % (image.shape[2]))
# Out:
# comprimento (w): 183 pixels
# altura (h): 275 pixels
# canais (w): 3 pixels

# %%
#mostrar uma imagem
imagem = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20, 10))
plt.imshow(imagem)

# %%
#salvar uma imagem
cv2.imwrite("img/russian2.jpg", image)
# Out:
# True

# %%
#convertendo uma imagem para escala de cinza
imagem_gray = cv2.imread('img/russian2.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(20, 10))
plt.imshow(imagem_gray, cmap="gray")
